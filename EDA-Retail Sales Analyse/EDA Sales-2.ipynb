# %% [markdown]
# <font size = 8>EDA- RETAIL SALES ANALAYSES
# By HIMANSHU </font>

# %% [markdown]
# <font size = 5>**Import Libraries**</font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# <font size = 5>**Read Data**</font>

# %%
dataset  = pd.read_csv("SampleSuperstore.csv")
dataset.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
dataset.shape
# Out:
# (9994, 13)

# %% [markdown]
# <font size = 5>**Missing Values**</font>

# %%
dataset.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# <font size = 5>**Shipping Mode**</font>

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
x = dataset['Ship Mode'].value_counts().index
y = dataset['Ship Mode'].value_counts().values

plt.figure(figsize = (6,5))
plt.pie(y, labels = x,autopct = "%0.2f%%")
plt.legend(loc = 1)
plt.title('Shipping Mode')
# Out:
# Text(0.5, 1.0, 'Shipping Mode')

# %% [markdown]
# Outcomes ->
# 1.Maximum Orders are Shipped by Standard Class
# 2.Least Number of Orders are Shipped by Same Day

# %% [markdown]
# <font size = 5>**Types Of Orders**</font>

# %%
plt.figure(figsize = (5,3))
sns.countplot(x = "Segment", data = dataset)
plt.title("Types Of Orders")
plt.savefig("fig_name.jpg")
plt.show()

# %% [markdown]
# Outcomes ->
# 1. Maximum Orders are from Consumers
# 2. Least Orders are from Home Office

# %% [markdown]
# <font size = 5>**State-wise Sales**</font>

# %%
dataset['State'].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %% [markdown]
# Outcome ->
# 1.Top 5 Highest sales States are California, New York, Texas, Pennsylvania, Washington
# 2. Five Least Sales State are Wyoming, West Virginia, North Dakota, Maine, District of Columbia

# %% [markdown]
# <font size = 5>**Category-wise Orders**</font>

# %%
plt.figure(figsize = (5,3))
sns.countplot(x = "Category", data = dataset)
plt.title("Category-wise Orders")
# Out:
# Text(0.5, 1.0, 'Category-wise Orders')

# %% [markdown]
# Outcome ->
# 1. Orders are maximum from  Office Supplies Category
# 2. Least Orders are from Technology Category

# %% [markdown]
# <font size = 5>**Ship Mode As Per Category**</font>

# %%
#Sales via Ship mode
plt.figure(figsize = (7,4))
sns.countplot(x = "Ship Mode", data = dataset, hue = "Category")
plt.title("Ship Mode As Per Category")
# Out:
# Text(0.5, 1.0, 'Ship Mode As Per Category')

# %% [markdown]
# Outcomes ->
# 1. Highest orders from Office Supplies are transported from Standard class Ship Mode
# 2. Highest orders from Furniture are transported from Standard class Ship Mode
# 3. Highest orders from Technology are transported from Standard class Ship Mode
# 4. Least Orders from Office Supplies are transported from Same Day Ship Mode
# 5. Least Orders from Furniture are transported from Same Day Ship Mode
# 6. Least Orders from Technology are transported from Same Day Ship Mode

# %% [markdown]
# <font size = 5>**Sub-Category Wise Orders**</font>

# %%
plt.figure(figsize = (17,4))
sns.countplot(x = "Sub-Category", data = dataset)
plt.title("Sub-Category Wise Orders")
# Out:
# Text(0.5, 1.0, 'Sub-Category Wise Orders')

# %% [markdown]
# Outcomes ->
# 1. Maximum orders are of Binders
# 2. Minmum Orders are of Copiers

# %% [markdown]
# <font size = 5>**Category Wise Orders as per Sub-Category**</font>

# %%
plt.figure(figsize = (17,6))
sns.countplot(x = "Category", data = dataset, hue = "Sub-Category")
plt.title("Category Wise Orders as per Sub-Category")
# Out:
# Text(0.5, 1.0, 'Category Wise Orders as per Sub-Category')

# %% [markdown]
# <font size = 5>**Sub-Category wise orders of Furniture Category**</font>

# %%
plt.figure(figsize = (7,3))
sns.countplot(x = "Category", data = dataset[dataset["Category"]=="Furniture"], hue = "Sub-Category")
plt.title("Sub-Category wise orders of Furniture Category")
# Out:
# Text(0.5, 1.0, 'Sub-Category wise orders of Furniture Category')

# %% [markdown]
# Outcomes ->
# 1. Furnishings have the highest orders in Furniture Category
# 2. Bookcases have the least orders in Furniture Category

# %% [markdown]
# <font size = 5>**Sub-Category wise orders of Office Supplies**</font>

# %%
plt.figure(figsize = (9,5))
sns.countplot(x = "Category", data = dataset[dataset["Category"]=="Office Supplies"], hue = "Sub-Category")
plt.title("Sub-Category wise orders of Office Supplies")
# Out:
# Text(0.5, 1.0, 'Sub-Category wise orders of Office Supplies')

# %% [markdown]
# Outcomes ->
# 1. Binders have the Highest orders in Office Suppliers Category
# 2. Supplies have the Least orders in Office Suppliers Category

# %% [markdown]
# <font size = 5>**Sub-Category wise orders of Technology Category**</font>

# %%
plt.figure(figsize = (5,3))
sns.countplot(x = "Category", data = dataset[dataset["Category"]=="Technology"], hue = "Sub-Category")
plt.title("Sub-Category wise orders of Technology Category")
# Out:
# Text(0.5, 1.0, 'Sub-Category wise orders of Technology Category')

# %% [markdown]
# Outcomes ->
# 1. Phones have the Highest orders in Technology Category
# 2. Copiers have the Least orders in Technology Category

# %% [markdown]
# <font size = 5>**Category wise Sales**</font>

# %%
sales_by_category = dataset.groupby('Category')['Sales'].sum()
print(sales_by_category)
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
plt.figure(figsize = (5,3))
sns.barplot(x = "Category",y = "Sales", data = dataset, estimator = 'sum')
plt.title("Category wise Sales")
# Out:
# Text(0.5, 1.0, 'Category wise Sales')

# %% [markdown]
# Outcomes ->
# 1. Highest Sales is from Technology Category
# 2. Least Sales is from Office Supplies Category

# %% [markdown]
# <font size = 5>**Sales by Sub-Category**</font>

# %%
sales_by_sub_category = dataset.groupby('Sub-Category')['Sales'].sum()
print(sales_by_sub_category)
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
plt.figure(figsize = (17,6))
sns.barplot(x = "Sub-Category",y = "Sales", data = dataset, estimator = 'sum')
plt.title("Sub-Category wise Sales")
# Out:
# Text(0.5, 1.0, 'Sub-Category wise Sales')

# %% [markdown]
# Outcomes ->
# 1. Phones have the Highest Sales
# 2. Fasteners have the Least Sales

# %% [markdown]
# <font size = 5>**Profit by Category**</font>

# %%
profit_by_category = dataset.groupby('Category')['Profit'].sum()
print(profit_by_category)
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
plt.figure(figsize = (5,3))
sns.barplot(x = "Category",y = "Profit", data = dataset, estimator = 'sum')
plt.title("Category-Wise Profit")
# Out:
# Text(0.5, 1.0, 'Category-Wise Profit')

# %% [markdown]
# Outcomes ->
# 1. Technolgy Category have the Highest Profit
# 2. Furniture Category have the Least Profit

# %% [markdown]
# <font size = 5>**Profit by Sub-Category**</font>

# %%
profit_by_sub_category = dataset.groupby('Sub-Category')['Profit'].sum()
print(profit_by_sub_category)
# Out:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6527.7870
# Binders        30221.7633
# Bookcases      -3472.5560
# Chairs         26590.1663
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13059.1436
# Labels          5546.2540
# Machines        3384.7569
# Paper          34053.5693
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
plt.figure(figsize = (18,6))
sns.barplot(x = "Sub-Category",y = "Profit", data = dataset, estimator = 'sum')
plt.title("Sub-Category-Wise Profit")
# Out:
# Text(0.5, 1.0, 'Sub-Category-Wise Profit')

# %% [markdown]
# Outcomes->
# 1. Copiers have the Highest Profit
# 2. Fasteners have the Least Profit
# 3. Bookcases, Tables, Supplies Sub-Category have the Loss
# 4. Supplies have the least Loss
# 5. Tables have the Maximum Loss

# %% [markdown]
# <font size = 5>**Sub-Category wise Quantity Sales**</font>

# %%
Quantity_sales_by_sub_category = dataset.groupby('Sub-Category')['Quantity'].sum()
print(Quantity_sales_by_sub_category)
# Out:
# Sub-Category
# Accessories    2976
# Appliances     1729
# Art            3000
# Binders        5974
# Bookcases       868
# Chairs         2356
# Copiers         234
# Envelopes       906
# Fasteners       914
# Furnishings    3563
# Labels         1400
# Machines        440
# Paper          5178
# Phones         3289
# Storage        3158
# Supplies        647
# Tables         1241
# Name: Quantity, dtype: int64

# %%
plt.figure(figsize = (17,6))
sns.barplot(x = "Sub-Category",y = "Quantity", data = dataset, estimator = 'sum')
plt.title("Sub-Category wise Quantity Sales")
# Out:
# Text(0.5, 1.0, 'Sub-Category wise Quantity Sales')

# %% [markdown]
# Outcomes ->
# 1. Binders are Maximum Saled
# 2. Copiers are Least Saled
